# %%
from graph.workflow import build_workflow

app = build_workflow()
print(app.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	supervisor(supervisor)
# 	quran_agent(quran_agent)
# 	hadith_agent(hadith_agent)
# 	conversation_agent(conversation_agent)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> supervisor;
# 	supervisor -. &nbsp;conversation&nbsp; .-> conversation_agent;
# 	supervisor -. &nbsp;hadith&nbsp; .-> hadith_agent;
# 	supervisor -. &nbsp;quran&nbsp; .-> quran_agent;
# 	conversation_agent --> __end__;
# 	hadith_agent --> __end__;
# 	quran_agent --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
from graph.workflow import build_workflow 
app = build_workflow()
print(app.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	supervisor(supervisor)
# 	quran_agent(quran_agent)
# 	hadith_agent(hadith_agent)
# 	conversation_agent(conversation_agent)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> supervisor;
# 	supervisor -. &nbsp;conversation&nbsp; .-> conversation_agent;
# 	supervisor -. &nbsp;hadith&nbsp; .-> hadith_agent;
# 	supervisor -. &nbsp;quran&nbsp; .-> quran_agent;
# 	conversation_agent --> __end__;
# 	hadith_agent --> __end__;
# 	quran_agent --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
from graph.workflow import build_workflow
app = build_workflow()
print(app.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	supervisor(supervisor)
# 	quran_agent(quran_agent)
# 	hadith_agent(hadith_agent)
# 	conversation_agent(conversation_agent)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> supervisor;
# 	supervisor -. &nbsp;conversation&nbsp; .-> conversation_agent;
# 	supervisor -. &nbsp;hadith&nbsp; .-> hadith_agent;
# 	supervisor -. &nbsp;quran&nbsp; .-> quran_agent;
# 	conversation_agent --> __end__;
# 	hadith_agent --> __end__;
# 	quran_agent --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
from graph.workflow import build_workflow
app = build_workflow()
print(app.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	supervisor(supervisor)
# 	quran_agent(quran_agent)
# 	hadith_agent(hadith_agent)
# 	conversation_agent(conversation_agent)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> supervisor;
# 	supervisor -. &nbsp;conversation&nbsp; .-> conversation_agent;
# 	supervisor -. &nbsp;hadith&nbsp; .-> hadith_agent;
# 	supervisor -. &nbsp;quran&nbsp; .-> quran_agent;
# 	conversation_agent --> __end__;
# 	hadith_agent --> __end__;
# 	quran_agent --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
